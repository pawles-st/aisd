# %%
import numpy as np
from matplotlib import pyplot as plt
import math

# %%
X = np.arange(100, 5001, 100)
Y = []
results = open("lcs/results.txt", "r")
lines = results.readlines()
for line in lines:
    Y.append(int(line.rstrip("\n")))
plt.plot(X, Y)

# %%
X = np.arange(100, 10001, 100)
Y = []
results = open("binomial_heap/results.txt", "r")
lines = results.readlines()
for line in lines:
    Y.append(int(line.rstrip("\n")))
plt.plot(X, Y)

# %%
X = np.arange(100, 10001, 100)
Y = []
results = open("fibonacci_heap/results.txt", "r")
lines = results.readlines()
for line in lines:
    Y.append(int(line.rstrip("\n")))
plt.plot(X, Y)

# %%
X = np.arange(100, 10001, 100)
Y1 = []
results = open("binomial_heap/results.txt", "r")
lines = results.readlines()
for line in lines:
    Y1.append(int(line.rstrip("\n")))
plt.plot(X, Y1)
X = np.arange(100, 10001, 100)
Y2 = []
results = open("fibonacci_heap/results.txt", "r")
lines = results.readlines()
for line in lines:
    Y2.append(int(line.rstrip("\n")))
plt.plot(X, Y2)
